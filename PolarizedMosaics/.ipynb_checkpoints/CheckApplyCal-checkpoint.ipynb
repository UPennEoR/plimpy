# %%
from pyuvdata import UVData, UVCal, utils
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
stem = 'zen.2458098.22991'
raw_path = '/lustre/aoc/projects/hera/H1C_IDR2/2458098/'
raw_file = raw_path+stem+'.HH.uvh5'
cal_path = '/lustre/aoc/projects/hera/H1C_IDR2/IDR2_2/2458098/'
cal_file = cal_path+stem+'.HH.smooth_abs.calfits'
out_path = '/lustre/aoc/projects/hera/jaguirre/PolarizedMosaics/Test/'
out_file = out_path+stem+'.HH.calibrated.uvh5'
print(raw_file)
print(cal_file)
#apply_cal.py --new_cal=/lustre/aoc/projects/hera/H1C_IDR2/IDR2_2/2458098/zen.2458098.12552.HH.reflections.calfits 
#--filetype_in uvh5 --filetype_out uvh5 
# /lustre/aoc/projects/hera/H1C_IDR2/IDR2_2/2458098/zen.2458098.12552.HH.uvh5 
# /zen.2458098.12552.HH.calibrated.uvh5
print()
print('apply_cal.py --new_cal '+cal_file + ' --filetype_in uvh5 --filetype_out uvh5 '+raw_file+' '+out_file)
# Out:
# /lustre/aoc/projects/hera/H1C_IDR2/2458098/zen.2458098.22991.HH.uvh5
# /lustre/aoc/projects/hera/H1C_IDR2/IDR2_2/2458098/zen.2458098.22991.HH.smooth_abs.calfits
#
# apply_cal.py --new_cal /lustre/aoc/projects/hera/H1C_IDR2/IDR2_2/2458098/zen.2458098.22991.HH.smooth_abs.calfits --filetype_in uvh5 --filetype_out uvh5 /lustre/aoc/projects/hera/H1C_IDR2/2458098/zen.2458098.22991.HH.uvh5 /lustre/aoc/projects/hera/jaguirre/PolarizedMosaics/Test/zen.2458098.22991.HH.calibrated.uvh5

# %%
uvd = UVData()
uvd.read(raw_file)

# %%
uvc = UVCal()
uvc.read_calfits(cal_file)

# %%
t0 = time.time()
uv_calibrated = utils.uvcalibrate(uvd, uvc, inplace=False)
t1 = time.time()
print(t1-t0)
# Out:
# 22.118893146514893

# %%
bl = (26, 27, 'xx')
blraw = uvd.select(bls=bl,inplace=False)

# %%
blcal = uv_calibrated.select(bls=bl,inplace=False)

# %%
blraw.data_array.shape
# Out:
# (60, 1, 1024, 1)

# %%
plt.imshow(np.log10(np.abs(blraw.data_array.squeeze()/~blraw.flag_array.squeeze())),aspect='auto')
# Out:
# divide by zero encountered in log10

# %%
plt.imshow(np.log10(np.abs(blcal.data_array.squeeze()/~blcal.flag_array.squeeze())),aspect='auto')
# Out:
# divide by zero encountered in true_divide
# invalid value encountered in true_divide

# %%
plt.imshow(np.angle(blraw.data_array.squeeze()/~blraw.flag_array.squeeze()), aspect='auto')

# %%
plt.imshow(np.angle(blcal.data_array.squeeze())/~blcal.flag_array.squeeze(), aspect='auto')
# Out:
# divide by zero encountered in true_divide
# invalid value encountered in true_divide

# %%
plt.imshow(np.angle(blcal.data_array.squeeze()-blraw.data_array.squeeze()), aspect='auto')
plt.colorbar()

# %%
plt.plot(np.abs(uvc.gain_array[uvc.ant2ind(26),0,:,0,0]))
plt.plot(np.abs(uvc.gain_array[uvc.ant2ind(27),0,:,0,0]))
plt.ylim([0,0.05])
# Out:
# (0, 0.05)

# %%
uvc.flag_array[uvc.ant2ind(52),0,:,:,0].sum()/(60*1024)
# Out:
# 0.6254557291666667

# %%
uvc.flag_array[uvc.ant2ind(53),0,:,:,0].sum()/(60*1024)
# Out:
# 1.0

# %%
uvc.flag_array.sum()/np.product(np.array(uvc.flag_array.shape))
# Out:
# 0.7479028946314102

# %%
uvd.flag_array.sum()
# Out:
# 0

# %%
uv_calibrated.flag_array.sum()/(np.product(np.array(uv_calibrated.flag_array.shape)))
# Out:
# 0.8287642303156749

# %%
uvc.ant_array
# Out:
# array([  0,   1,   2,  11,  12,  13,  14,  23,  24,  25,  26,  27,  36,
#         37,  38,  39,  40,  41,  50,  51,  52,  53,  54,  55,  65,  66,
#         67,  68,  69,  70,  71,  82,  83,  84,  85,  86,  87,  88,  98,
#        120, 121, 122, 123, 124, 136, 137, 138, 139, 140, 141, 142, 143])

# %%
uvc.flag_array.shape
# Out:
# (52, 1, 1024, 60, 2)

# %%
for ant in uvc.ant_array:
    print(ant,uvc.flag_array[uvc.ant2ind(ant),0,:,:,0].sum()/(1024*60.),uvc.flag_array[uvc.ant2ind(ant),0,:,:,1].sum()/(1024*60.))
# Out:
# 0 1.0 1.0
# 1 0.6254557291666667 0.6254557291666667
# 2 1.0 1.0
# 11 1.0 1.0
# 12 0.6254557291666667 0.6254557291666667
# 13 0.6254557291666667 0.6254557291666667
# 14 1.0 1.0
# 23 0.6254557291666667 0.6254557291666667
# 24 1.0 1.0
# 25 0.6254557291666667 0.6254557291666667
# 26 0.6254557291666667 0.6254557291666667
# 27 0.6254557291666667 0.6254557291666667
# 36 0.6254557291666667 0.6254557291666667
# 37 0.6254557291666667 0.6254557291666667
# 38 0.6254557291666667 0.6254557291666667
# 39 0.6254557291666667 0.6254557291666667
# 40 0.6254557291666667 0.6254557291666667
# 41 0.6254557291666667 0.6254557291666667
# 50 1.0 1.0
# 51 0.6254557291666667 0.6254557291666667
# 52 0.6254557291666667 0.6254557291666667
# 53 1.0 1.0
# 54 1.0 1.0
# 55 0.6254557291666667 0.6254557291666667
# 65 0.6254557291666667 0.6254557291666667
# 66 0.6254557291666667 0.6254557291666667
# 67 1.0 1.0
# 68 0.6254557291666667 0.6254557291666667
# 69 1.0 1.0
# 70 0.6254557291666667 0.6254557291666667
# 71 0.6254557291666667 0.6254557291666667
# 82 0.6254557291666667 0.6254557291666667
# 83 0.6254557291666667 0.6254557291666667
# 84 0.6254557291666667 0.6254557291666667
# 85 0.6254557291666667 0.6254557291666667
# 86 0.6254557291666667 0.6254557291666667
# 87 0.6254557291666667 0.6254557291666667
# 88 0.6254557291666667 0.6254557291666667
# 98 1.0 1.0
# 120 0.6254557291666667 0.6254557291666667
# 121 0.6254557291666667 0.6254557291666667
# 122 1.0 1.0
# 123 0.6254557291666667 0.6254557291666667
# 124 0.6254557291666667 0.6254557291666667
# 136 1.0 1.0
# 137 1.0 1.0
# 138 1.0 1.0
# 139 1.0 1.0
# 140 1.0 1.0
# 141 0.6254557291666667 0.6254557291666667
# 142 0.6254557291666667 0.6254557291666667
# 143 0.6254557291666667 0.6254557291666667
